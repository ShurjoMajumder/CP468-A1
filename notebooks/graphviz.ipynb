# %%
from sim.gen_matrix import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sim.gen_matrix import *
#
# File ~\PycharmProjects\CP468-A1\sim\gen_matrix.py:7
#       4 import networkx as nx
#       5 import iplotx as ipx
# ----> 7 from graphviz import Digraph
#       8 from numpy import dtype, ndarray
#       9 from scipy import sparse
#
# ModuleNotFoundError: No module named 'graphviz'
